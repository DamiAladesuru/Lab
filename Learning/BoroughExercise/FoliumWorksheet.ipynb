# %% [markdown]
# ### Import dataset

# %%
import pandas as pd
import numpy as np

# %%
gas = pd.read_csv("C:/Users/aladesuru/Downloads/Natural_Gas_Consumption_by_ZIP_Code_-_2010_20240521.csv")
gas.head()
# Out:
#    Zip Code Building type (service class  Consumption (therms)   \
# 0     10451                   Commercial              8,071,587
# 1     10468                  Residential                907,812
# 2     11212                Institutional              1,441,719
# 3     11420            Small residential              9,694,601
# 4     11694                   Commercial              2,058,660
#
#   Utility/Data Source   Latitude  Longitude
# 0               ConEd  40.820696 -73.923841
# 1               ConEd  40.869693 -73.898927
# 2       National Grid  40.662797 -73.912985
# 3       National Grid  40.673345 -73.817707
# 4       National Grid  40.576578 -73.850777

# %%
# Check data types of gas accounts dataframe

gas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 964 entries, 0 to 963
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Zip Code                      964 non-null    int64
#  1   Building type (service class  964 non-null    object
#  2    Consumption (therms)         955 non-null    object
#  3   Utility/Data Source           964 non-null    object
#  4   Latitude                      964 non-null    float64
#  5   Longitude                     964 non-null    float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 45.3+ KB

# %%
missing_values = gas[gas.isnull().any(axis=1)]
gas.isnull().any(axis=1).sum()
# Out:
# 9

# %%
gas = gas.dropna()
gas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 955 entries, 0 to 963
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Zip Code                      955 non-null    int64
#  1   Building type (service class  955 non-null    object
#  2    Consumption (therms)         955 non-null    object
#  3   Utility/Data Source           955 non-null    object
#  4   Latitude                      955 non-null    float64
#  5   Longitude                     955 non-null    float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 52.2+ KB

# %% [markdown]
# ## Import folium package and map types.<br/><br/> We will import Choropleth, HeatMap, Marker, MarkerCluster, and Circle Maps

# %%
import folium # html mapping package
from folium import Choropleth, Circle, Marker 
from folium.plugins import HeatMap, MarkerCluster

# %% [markdown]
# ## Marker Map

# %% [markdown]
# ### Display blank basemap using folium

# %%
map1 = folium.Map(location = [np.mean(gas['Latitude']), np.mean(gas['Longitude'])], tiles = 'OpenStreetMap', zoom_start = 8)
map1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_04eb9e76b50c9b0fa290779a2526ea76 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_04eb9e76b50c9b0fa290779a2526ea76&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_04eb9e76b50c9b0fa290779a2526ea76 = L.map(
#                 &quot;map_04eb9e76b50c9b0fa290779a2526ea76&quot;,
#                 {
#                     center: [40.72729225892146, -70.04479843398951],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_df74fed88d6bedde0afcc78ad50e0471 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_df74fed88d6bedde0afcc78ad50e0471.addTo(map_04eb9e76b50c9b0fa290779a2526ea76);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Add markers to basemap using Marker in Folium using folium.Marker() and a loop for each marker. <br/> <br/>Each marker represents a different gas account

# %%
# iterate through each row
for idx, row in gas.iterrows():
    
# Add marker for each gas accounts 
    Marker([row['Latitude'], row['Longitude']]). add_to(map1) 
map1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_04eb9e76b50c9b0fa290779a2526ea76 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_04eb9e76b50c9b0fa290779a2526ea76&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_04eb9e76b50c9b0fa290779a2526ea76 = L.map(
#                 &quot;map_04eb9e76b50c9b0fa290779a2526ea76&quot;,
#                 {
#                     center: [40.72729225892146, -70.04479843398951],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_df74fed88d6bedde0afcc78ad50e0471 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_df74fed88d6bedde0afcc78ad50e0471.addTo(map_04eb9e76b50c9b0fa290779a2526ea76);
#
#
#             tile_layer_df74fed88d6bedde0afcc78ad50e0471.addTo(map_04eb9e76b50c9b0fa290779a2526ea76);
#
#
#             var marker_85cb674005f394747573010fd549a70b = L.marker(
#                 [40.82069641, -73.92384137],
#                 {}
#             ).addTo(map_04eb9e76b50c9b0fa290779a2526ea76);
#
#
#             var marker_9f0d0e247b27dc6fe8fd691f50364676 = L.marker(
#                 [40.869693, -73.89892699],
#                 {}
#             ).addTo(map_04eb9e76b50c9b0fa290779a2526ea76);
#
#
#             var marker_96d35a6b6daf9b7972773e532980c0cb = L.marker(
#                 [40.66279717, -73.91298489],
#                 {}
#             ).addTo(map_04eb9e76b50c9b0fa290779a2526ea76);
#
#
#             var marker_431c743179ed3562e8f2e2f1f7cbf725 = L.marker(
#                 [40.67334524, -73.81770717],
#                 {}
#             ).addTo(map_04eb9e76b50c9b0fa290779a2526ea76);
#
#
#             var marker_f1a50528785cf87e762bb92e4b565a53 = L.marker(
#                 [40.57657831, -73.850777],
#                 {}
#             ).addTo(map_04eb9e76b50c9b0fa290779a2526ea76);
#
#
#             var marker_b8a69877817a2fe9c167fac2dcfde2ab = L.marker(
#                 [40.62772226, -73.94653792],
#                 {}
#             ).addTo(map_04eb9e76b50c9b0fa290779a2526ea76);
#
#
#             var marker_c10f33b8a0e34698979c16936eede9d6 = L.marker(
#                 [40.53039312, -74.21893861],
#                 {}
#             ).addTo(map_04eb9e76b50c9b0fa290779a2526ea76);
#
#
#             var marker_51302d34d086937b843a3b0215521ed0 = L.marker(
#                 [40.87061711, -73.92422326],
#                 {}
#             ).addTo(map_04eb9e76b50c9b0fa290779a2526ea76);
#
#
#             var marker_48c32d4a1b748bc3fc9366d1a1e5a3f6 = L.marker(
#                 [40.66161349, -73.73605173],
#                 {}
#             ).addTo(map_04eb9e76b50c9b0fa290779a2526ea76);
#
#
#             var marker_d5c8b4d74160829f1c97be3f46b88253 = L.marker(
#                 [40.76197649, -73.94999967],
#                 {}
#             ).addTo(map_04eb9e76b50c9b0fa290779a2526ea76);
#
#
#             var marker_66c23f53b0efbe14e650d0905e434a7a = L.marker(
#                 [40.73914078, -73.98289846],
#                 {}
#             ).addTo(map_04eb9e76b50c9b0fa290779a2526ea76);
#
#
#             var marker_2a65a917c1f277158a8894c6483441ac = L.marker(
#                 [40.76035097, -73.79632646],
#                 {}
#             ).addTo(map_04eb9e76b50c9b0fa290779a2526ea76);
#
#
#             var marker_fb99a308223c7c1f839a88bab38c56d7 = L.marker(
#                 [40.73704138, -73.724157],
#                 {}
#             ).addTo(map_04eb9e76b50c9b0fa290779a2526ea76);
#
#
#             var marker_14a65c1c905e1a6e3676365be7449733 = L.marker(
#                 [40.71311535, -73.792821],
#                 {}
#             ).addTo(map_04eb9e76b50c9b0fa290779a2526ea76);
#
#
#             var marker_d7c1ca79173f9be5984d9635d8f4641e = L.marker(
#                 [40.70409574, -73.92099423],
#                 {}
#             ).addTo(map_04eb9e76b50c9b0fa290779a2526ea76);
#
#
#             var marker_d4cd5fae5e2656f6a195691a763b0ce5 = L.marker(
#                 [40.64118493, -74.01676473],
#                 {}
#             ).addTo(map_04eb9e76b50c9b0fa290779a2526ea76);
#
#
#             var marker_3bfac7f7b2227b4180b499bfa2b465c3 = L.marker(
#                 [40.75907422, -73.73430018],
#                 {}
#             ).addTo(map_04eb9e76b50c9b0fa290779a2526ea76);
#
#
#             var marker_e38b5694d4b51ffafed297c2c76831b2 = L.marker(
#                 [40.74570245, -73.93866903],
#                 {}
#             ).addTo(map_04eb9e76b50c9b0fa290779a2526ea76);
#
#
#             var marker_767db9a0c3acd3026e34f2a04f8edee5 = L.marker(
#                 [40.70191202, -73.9423792],
#                 {}
#             ).addTo(map_04eb9e76b50c9b0fa290779a2526ea76);
#
#
#             var marker_33aa8b99770931fd17e2963a51bc466d = L.marker(
#                 [40.82668193, -73.93777091],
#                 {}

# %% [markdown]
# ### There are too many markers to get a good idea of where our accounts are concentrated.<br/><br/> With a MarkerCluster Map we can get a better idea of where our accounts are located since accounts in close proximity to one another are grouped together.

# %% [markdown]
# ## MarkerCluster Map

# %%
# Define new map

map2 = folium.Map([np.mean(gas['Latitude']), np.mean(gas['Longitude'])], tiles = 'OpenStreetMap', zoom_start = 8)

#Define MarkerCluster object

mc = MarkerCluster(name = 'Clustered Accounts')

# Loop through gas accounts DataFrame and add gas accounts to MarkerCluster objects
for idx, row in gas.iterrows():
    mc.add_child(Marker([row['Latitude'], row['Longitude']]))
    
map2.add_child(mc)

map2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d50bd0ccc69c84881d64c115b2f4da11 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d50bd0ccc69c84881d64c115b2f4da11&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d50bd0ccc69c84881d64c115b2f4da11 = L.map(
#                 &quot;map_d50bd0ccc69c84881d64c115b2f4da11&quot;,
#                 {
#                     center: [40.72729225892146, -70.04479843398951],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b0074e50378ea80733e33d1c9785c042 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_b0074e50378ea80733e33d1c9785c042.addTo(map_d50bd0ccc69c84881d64c115b2f4da11);
#
#
#             var marker_cluster_16a1ebb5a1c008b5ab41e0d22ba274b9 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_3b74343e63b6b946dfd1f0ffbefefa8f = L.marker(
#                 [40.82069641, -73.92384137],
#                 {}
#             ).addTo(marker_cluster_16a1ebb5a1c008b5ab41e0d22ba274b9);
#
#
#             var marker_244a20f9988f312a892cae6c1569335f = L.marker(
#                 [40.869693, -73.89892699],
#                 {}
#             ).addTo(marker_cluster_16a1ebb5a1c008b5ab41e0d22ba274b9);
#
#
#             var marker_95b2589a036b58de83856eeb00608a4b = L.marker(
#                 [40.66279717, -73.91298489],
#                 {}
#             ).addTo(marker_cluster_16a1ebb5a1c008b5ab41e0d22ba274b9);
#
#
#             var marker_a11d5cc2600d1f6b3c1c297c63f0520e = L.marker(
#                 [40.67334524, -73.81770717],
#                 {}
#             ).addTo(marker_cluster_16a1ebb5a1c008b5ab41e0d22ba274b9);
#
#
#             var marker_098bd89ec850ccd22f98d727f3920c5e = L.marker(
#                 [40.57657831, -73.850777],
#                 {}
#             ).addTo(marker_cluster_16a1ebb5a1c008b5ab41e0d22ba274b9);
#
#
#             var marker_687b777c9b0b98a8d9d899a206ddaec5 = L.marker(
#                 [40.62772226, -73.94653792],
#                 {}
#             ).addTo(marker_cluster_16a1ebb5a1c008b5ab41e0d22ba274b9);
#
#
#             var marker_aa4b8a0c2f1fb39cc5aaa5b340a3e6db = L.marker(
#                 [40.53039312, -74.21893861],
#                 {}
#             ).addTo(marker_cluster_16a1ebb5a1c008b5ab41e0d22ba274b9);
#
#
#             var marker_0c00c4ff7da8988aad91583c3df15202 = L.marker(
#                 [40.87061711, -73.92422326],
#                 {}
#             ).addTo(marker_cluster_16a1ebb5a1c008b5ab41e0d22ba274b9);
#
#
#             var marker_8cfd307e38396deeb3458617124998e6 = L.marker(
#                 [40.66161349, -73.73605173],
#                 {}
#             ).addTo(marker_cluster_16a1ebb5a1c008b5ab41e0d22ba274b9);
#
#
#             var marker_11943c9a04319174cfa95bb142d78f55 = L.marker(
#                 [40.76197649, -73.94999967],
#                 {}
#             ).addTo(marker_cluster_16a1ebb5a1c008b5ab41e0d22ba274b9);
#
#
#             var marker_c9102c7f3e2582dec81008090492e463 = L.marker(
#                 [40.73914078, -73.98289846],
#                 {}
#             ).addTo(marker_cluster_16a1ebb5a1c008b5ab41e0d22ba274b9);
#
#
#             var marker_5764e66af2e59d7ea5746f8eef98bb80 = L.marker(
#                 [40.76035097, -73.79632646],
#                 {}
#             ).addTo(marker_cluster_16a1ebb5a1c008b5ab41e0d22ba274b9);
#
#
#             var marker_ea9bc2787521f17e70086555e224c24a = L.marker(
#                 [40.73704138, -73.724157],
#                 {}
#             ).addTo(marker_cluster_16a1ebb5a1c008b5ab41e0d22ba274b9);
#
#
#             var marker_8efaede7c214b4693730bdc5b3606473 = L.marker(
#                 [40.71311535, -73.792821],
#                 {}
#             ).addTo(marker_cluster_16a1ebb5a1c008b5ab41e0d22ba274b9);
#
#
#             var marker_104ac52aac0ba1002cbeccc4aa169963 = L.marker(
#                 [40.70409574, -73.92099423],
#                 {}
#             ).addTo(marker_cluster_16a1ebb5a1c008b5ab41e0d22ba274b9);
#
#
#             var marker_7847e6cdab7b7eb6074def167f1a7231 = L.marker(
#                 [40.64118493, -74.01676473],
#                 {}
#             ).addTo(marker_cluster_16a1ebb5a1c008b5ab41e0d22ba274b9);
#
#
#             var marker_85c592200871f50559cf8302003ef99f = L.marker(
#                 [40.75907422, -73.734300

# %% [markdown]
# ### If we go back to the dataset we can see that the gas accounts are either coming from National Grid or ConEd.<br/><br/> How can we visualize our National Grid accounts seperate from our ConEd accounts?<br/><br/>One way to do this is by creating a HeatMap

# %%
gas.head()
# Out:
#    Zip Code Building type (service class)  Consumption (therms)  \
# 0     11109                    Commercial               45899.0
# 1     11429                    Commercial                 755.0
# 2     11226                    Industrial               65835.0
# 3     10314                 Institutional             2294516.0
# 4     11223                    Commercial             2376036.0
#
#   Utility/Data Source   Latitude  Longitude
# 0               ConEd  40.744415 -73.957702
# 1               ConEd  40.709913 -73.738640
# 2       National Grid  40.646505 -73.957190
# 3       National Grid  40.596490 -74.165991
# 4       National Grid  40.596940 -73.973311

# %%
gas['Utility/Data Source'].value_counts()
# Out:
# ConEd            518
# National Grid    446
# Name: Utility/Data Source, dtype: int64

# %% [markdown]
# ## HeatMap

# %%
# Define new map

map3 = folium.Map([np.mean(gas['Latitude']), np.mean(gas['Longitude'])], tiles = 'OpenStreetMap', zoom_start = 8)

# Define HeatMap object for National Grid accounts

HeatMap(gas[gas['Utility/Data Source'] == 'National Grid'][['Latitude', 'Longitude']], radius = 10,
        gradient = {.5: 'purple', .65: 'yellow', 1: 'white'}, name = 'Heat Map of National Grid Accounts').add_to(map3)

# Define HeatMap object for ConEd accounts 

HeatMap(gas[gas['Utility/Data Source'] == 'ConEd'][['Latitude', 'Longitude']], radius = 10,
        gradient = {.5: 'black', .65: 'red', 1: 'gold'}, name = 'ConEd').add_to(map3)

# Add layer control to toggle between National Grid and ConEd accounts

folium.LayerControl().add_to(map3)

# Display Map

map3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2fbbfb0857dfe4fee7db06471d3952c7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2fbbfb0857dfe4fee7db06471d3952c7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2fbbfb0857dfe4fee7db06471d3952c7 = L.map(
#                 &quot;map_2fbbfb0857dfe4fee7db06471d3952c7&quot;,
#                 {
#                     center: [40.72729225892146, -70.04479843398951],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a9a4204966876ef6243783203f904369 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_a9a4204966876ef6243783203f904369.addTo(map_2fbbfb0857dfe4fee7db06471d3952c7);
#
#
#             var heat_map_cd063b86e6f20baa5cddbe681fb2cedd = L.heatLayer(
#                 [[40.66279717, -73.91298489], [40.67334524, -73.81770717], [40.57657831, -73.850777], [40.62772226, -73.94653792], [40.53039312, -74.21893861], [40.73704138, -73.724157], [40.70409574, -73.92099423], [40.64118493, -74.01676473], [40.70191202, -73.9423792], [40.5964903, -74.16599112], [40.646505, -73.9571901], [40.67334524, -73.81770717], [40.73704138, -73.724157], [40.70991312, -73.73864032], [40.71158977, -73.95817675], [40.67571821, -73.79646501], [40.6233871, -74.03065295], [40.59693962, -73.97331147], [40.5964903, -74.16599112], [40.73987184, -73.79462154], [40.6183036, -73.82495532], [40.71679767, 73.87933421], [40.62772226, -73.94653792], [40.63083331, -74.1377343], [40.69128804, -73.92761793], [40.67755431, -74.0046767], [40.65451162, -74.00003393], [40.56602049, -74.11994567], [40.632789, -74.11645861], [40.6938821, -73.96433451], [40.5529353, -74.15130276], [40.70991312, -73.73864032], [40.6233871, -74.03065295], [40.6845781, -73.84960167], [40.7172223, -73.7671415], [40.68075867, -73.94926775], [40.60123351, -73.94436854], [40.55962437, -73.910063], [40.72139696, -73.7419373], [40.70191202, -73.9423792], [40.67755431, -74.0046767], [40.69467826, -73.98992087], [40.50800453, -74.24211428], [40.66161349, -73.73605173], [40.62678551, -74.09611291], [40.632789, -74.11645861], [40.60793409, -74.02694267], [40.67122517, -73.93644337], [40.6497216, -73.93427609], [40.65817023, -73.84496264], [40.72139696, -73.7419373], [40.62192951, -73.96551106], [40.70119265, -73.80979666], [40.5529353, -74.15130276], [40.6183036, -73.82495532], [40.61636867, -73.92773225], [40.64722933, -73.78637495], [40.70828608, -73.82855612], [40.57841411, -73.94026], [40.71158977, -73.95817675], [40.7172223, -73.7671415], [40.56602049, -74.11994567], [40.71679767, -73.87933421], [40.62678551, -74.09611291], [40.6823121, -73.97956719], [40.56602049, -74.11994567], [40.69176459, -73.85702229], [40.59618469, -74.07507238], [40.59618469, -74.07507238], [40.74519376, -73.90484714], [40.72646492, -73.86148085], [40.72139696, -73.7419373], [40.646505, -73.9571901], [40.63277296, -73.99667681], [40.72931057, -73.75067602], [40.71311535, 73.792821], [40.74967822, -73.85304069], [40.75935377, 73.891844], [40.66317006, -73.95370111], [40.7214531, -73.9085435], [40.6938821, -73.96433451], [40.76341327, -73.8723789], [40.67334524, -73.81770717], [40.68503, -73.978075], [40.63083331, -74.1377343], [40.59693962, -73.97331147], [40.63303231, -74.16834885], [40.73032309, -73.82610631], [40.62192951, -73.96551106], [40.64322701, -73.97644862], [40.57657831, -73.850777], [40.70122489, -73.88334858], [40.59313389, -73.79540208], [40.75163074, -73.88361255], [40.70122489, -73.88334858], [40.5529353, -74.15130276], [40.67122517, -73.93644337], [40.75935377, -73.891844], [40.63083331, -74.1377343], [40.69429334, -73.73568329], [40.71158977, -73.95817675], [40.61654071, -74.01327785], [40.60123351, -73.94436854], [40.66555725, -73.97968154], [40.67636373, -73.84454276], [40.72931057, -73.75067602], [40.74519376, -73.90484714], [40.6233871, -74.03065295], [40.54295598, -74.18037682], [40.57630466, -73.999532], [40.61636867, -73.92773225], [40.69176459, -73.85702229], [40.64002149, -73.90112194], [40.6183036, -73.82495532], [40.66161349, -73.73605173], [40.74967822, -73.85304069], [40.75935377, -73.891844], [40.60793409, -74.02694267], [40.70122489, -73.88334858], [40.6823121, -73.97956719], [40.68075867, -73.94926775], [40.62678551, -74.09611291], [40.6233871, -74.03065295], [40.6938821, -73.96433451], [40.60401181, -74.000969], [40.61654071, -74.01327785], [40.67080243, -73.89384115], [40.64949608, 73.865525], [40.76341327, -73.8723789], [40.57841411, -73.94026], [40.64322701, -73.97644862], [40.57630466, -73.999532], [40.69637041, -73.84031025], [40.59618469, -74.07507238], [40.75163074, -73.88361255], [40.71311535, 73.792821], [40.60401181, -74.000969], [40.77556737, -73.

# %% [markdown]
# ## Bubble Map

# %% [markdown]
# ### If we go back again to the to the dataset we can see that the account types are in the Building (service class) column.

# %%
gas.head()
# Out:
#    Zip Code Building type (service class)  Consumption (therms)  \
# 0     11109                    Commercial               45899.0
# 1     11429                    Commercial                 755.0
# 2     11226                    Industrial               65835.0
# 3     10314                 Institutional             2294516.0
# 4     11223                    Commercial             2376036.0
#
#   Utility/Data Source   Latitude  Longitude
# 0               ConEd  40.744415 -73.957702
# 1               ConEd  40.709913 -73.738640
# 2       National Grid  40.646505 -73.957190
# 3       National Grid  40.596490 -74.165991
# 4       National Grid  40.596940 -73.973311

# %%
# value counts for Building type

gas['Building type (service class)'].value_counts()
# Out:
# Commercial           338
# Residential          198
# Large residential    165
# Small residential     96
# Institutional         86
# Industrial            81
# Name: Building type (service class), dtype: int64

# %% [markdown]
# ### How could we visualize each of these account types using a Bubble Map?

# %%
# Define a new map

map4 = folium.Map(location = [np.mean(gas['Latitude']), np.mean(gas['Longitude'])], tiles = 'OpenStreetMap', 
                  zoom_start = 10)

# Color function 

def bubble_color(val):
    if val == 'National Grid':
        return 'purple'
    else:
        return 'red'


# Add Bubble layer to map using folium Circle function

for i in range(len(gas)):
    Circle(location = [gas.iloc[i]['Latitude'], gas.iloc[i]['Longitude']], radius = 20, 
           color = bubble_color(gas.iloc[i]['Utility/Data Source'])).add_to(map4)


# Display map

map4
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0fda220296cd0bcb1c2d2fa7e5ac01a4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0fda220296cd0bcb1c2d2fa7e5ac01a4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0fda220296cd0bcb1c2d2fa7e5ac01a4 = L.map(
#                 &quot;map_0fda220296cd0bcb1c2d2fa7e5ac01a4&quot;,
#                 {
#                     center: [40.72729225892146, -70.04479843398951],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e863dcc8ccea0dbbb73a28528c5564ea = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_e863dcc8ccea0dbbb73a28528c5564ea.addTo(map_0fda220296cd0bcb1c2d2fa7e5ac01a4);
#
#
#             var circle_95872fdc957aa4a0c4d904ef76a90f62 = L.circle(
#                 [40.82069641, -73.92384137],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 20, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0fda220296cd0bcb1c2d2fa7e5ac01a4);
#
#
#             var circle_faf91b758c6218c9c9ea2a7cfc8ee4d4 = L.circle(
#                 [40.869693, -73.89892699],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 20, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0fda220296cd0bcb1c2d2fa7e5ac01a4);
#
#
#             var circle_2ac0785d9ae304a81b12e7b8f7fb7813 = L.circle(
#                 [40.66279717, -73.91298489],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;purple&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;purple&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 20, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0fda220296cd0bcb1c2d2fa7e5ac01a4);
#
#
#             var circle_d9d5e5769973591efef7de07e88f0591 = L.circle(
#                 [40.67334524, -73.81770717],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;purple&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;purple&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 20, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0fda220296cd0bcb1c2d2fa7e5ac01a4);
#
#
#             var circle_c710dba1050f04c36639b21df9de82dd = L.circle(
#                 [40.57657831, -73.850777],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;purple&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;purple&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 20, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0fda220296cd0bcb1c2d2fa7e5ac01a4);
#
#
#             var circle_03fcfa02bc163a49434af4d10afb9c10 = L.circle(
#                 [40.62772226, -73.94653792],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;purple&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;purple&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 20, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0fda220296cd0bcb1c2d2fa7e5ac01a4);
#
#
#             var circle_1aff7d739c0880a06d6a76124b45cce6 = L.circle(
#                 [40.53039312, -74.21893861],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot

# %% [markdown]
# ## Choropleth Maps

# %% [markdown]
# ### Choropleth maps allow for pre-defined areas to be colored or patterned in proportion to a statisitical variable. For example, you could check for average housing values by state in a map where darker areas would have higher prices.<br/> <br/>Let's say we wanted to know which borough uses the most and which one uses the least.<br/><br/>We could figure this out with a spatial join between the borough shapefiles and

# %% [markdown]
# ### import geodata packages

# %%
import geopandas as gpd # Pandas GeodDataFrame
from geopandas.tools import sjoin # Join shapefiles to coordinate data
from shapely.geometry import Point # Geopoints

# %% [markdown]
# ### Create a GeoSeries to join latitudes and longitudes as points

# %%
# Define GeoSeries

points = gpd.GeoSeries(gas.apply(lambda x: Point(x['Longitude'], x['Latitude']), axis = 1), crs = {'init': 'epsg:4326'})

# Print GeoSeries

points.head()
# Out:
# c:\Users\aladesuru\.virtualenvs\Lab-wJx68UC_\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# 0    POINT (-73.92384 40.82070)
# 1    POINT (-73.89893 40.86969)
# 2    POINT (-73.91298 40.66280)
# 3    POINT (-73.81771 40.67335)
# 4    POINT (-73.85078 40.57658)
# dtype: geometry

# %%
# Make gas accounts GeoDataFrame
 
gas_gdf = gpd.GeoDataFrame(gas.drop(['Latitude', 'Longitude'], axis = 1) , geometry = points)
gas_gdf.head()
# Out:
#    Zip Code Building type (service class  Consumption (therms)   \
# 0     10451                   Commercial              8,071,587
# 1     10468                  Residential                907,812
# 2     11212                Institutional              1,441,719
# 3     11420            Small residential              9,694,601
# 4     11694                   Commercial              2,058,660
#
#   Utility/Data Source                    geometry
# 0               ConEd  POINT (-73.92384 40.82070)
# 1               ConEd  POINT (-73.89893 40.86969)
# 2       National Grid  POINT (-73.91298 40.66280)
# 3       National Grid  POINT (-73.81771 40.67335)
# 4       National Grid  POINT (-73.85078 40.57658)

# %% [markdown]
# ### We want to add the Neighborhood Tabulation Areas to our Map, but we need to extract them from a zipfile using the zipfile package

# %% [markdown]
# ### Get shapefiles from zip folder

# %%
# import zipfile package

import zipfile

# open zipfile with zipfile package

with zipfile.ZipFile('Your file path/Borough Boundaries (Water Areas Included).zip', 'r') as my_zip:
    print(my_zip.namelist())
    my_zip.extractall('files')
# Out:
# ['geo_export_49512982-8e61-4a09-91ce-6a6640b8d43c.dbf', 'geo_export_49512982-8e61-4a09-91ce-6a6640b8d43c.shp', 'geo_export_49512982-8e61-4a09-91ce-6a6640b8d43c.shx', 'geo_export_49512982-8e61-4a09-91ce-6a6640b8d43c.prj']

# %% [markdown]
# ### Store filenames from zip folder as variables

# %%
# Store filenames for zipfile files

dbf, shp, shx, prj = my_zip.namelist()

# Your local path

local_path = 'files/'

# %%
# read in borough shapefiles using read_file module

boroughs = gpd.read_file(local_path + shp)
boroughs.head()
# Out:
#    boro_code      boro_name    shape_area     shape_leng  \
# 0        1.0      Manhattan  9.442947e+08  203803.216852
# 1        2.0          Bronx  1.598380e+09  188054.198841
# 2        3.0       Brooklyn  2.684411e+09  234928.658563
# 3        4.0         Queens  3.858050e+09  429586.630985
# 4        5.0  Staten Island  2.539686e+09  212213.139971
#
#                                             geometry
# 0  MULTIPOLYGON (((-74.04388 40.69019, -74.04351 ...
# 1  POLYGON ((-73.86477 40.90201, -73.86305 40.901...
# 2  POLYGON ((-73.92722 40.72533, -73.92654 40.724...
# 3  POLYGON ((-73.77896 40.81171, -73.76371 40.793...
# 4  POLYGON ((-74.05581 40.64971, -74.05619 40.639...

# %% [markdown]
# ### Make sure boroughs shapefile and GeoDataFrame have same CRS

# %%
# Check crs for gas accounts

gas_gdf.crs
# Out:
# {'init': 'epsg: 4326'}

# %%
# Check crs  for boroughs shapefile

boroughs.crs
# Out:
# {'init': 'epsg:4326'}

# %%
# Change crs so both match 

boroughs.crs = {'init': 'epsg: 4326'}

# %% [markdown]
# ### Join our gas accounts to the boroughs shapefile using an inner spatial join

# %%
# sum join gas accounts to boroughs shapefile

gas_sum_join = gpd.sjoin().groupby().sum()

# mean join gas accounts to boroughs shapefile

gas_mean_join = gpd.sjoin().groupby().mean()

# count join gas accounts to boroughs shapefile

gas_counts_join = gpd.sjoin().groupby().count()

# %%
gas_sum_join['Consumption (therms)']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-f4862c35fcfe> in <module>
# ----> 1 gas_sum_join['Consumption (therms)']
#
# NameError: name 'gas_sum_join' is not defined

# %%
gas_mean_join['Consumption (therms)']
# Out:
# boro_name
# Bronx            2.663300e+06
# Brooklyn         5.005716e+06
# Manhattan        2.244163e+06
# Queens           2.172726e+06
# Staten Island    3.167656e+06
# Name: Consumption (therms), dtype: float64

# %%
boroughs
# Out:
#    boro_code      boro_name    shape_area     shape_leng  \
# 0        1.0      Manhattan  9.442947e+08  203803.216852
# 1        2.0          Bronx  1.598380e+09  188054.198841
# 2        3.0       Brooklyn  2.684411e+09  234928.658563
# 3        4.0         Queens  3.858050e+09  429586.630985
# 4        5.0  Staten Island  2.539686e+09  212213.139971
#
#                                             geometry
# 0  MULTIPOLYGON (((-74.04388 40.69019, -74.04351 ...
# 1  POLYGON ((-73.86477 40.90201, -73.86305 40.901...
# 2  POLYGON ((-73.92722 40.72533, -73.92654 40.724...
# 3  POLYGON ((-73.77896 40.81171, -73.76371 40.793...
# 4  POLYGON ((-74.05581 40.64971, -74.05619 40.639...

# %%
# Define new map 

map5 = folium.Map(location = [np.mean(gas['Latitude']), np.mean(gas['Longitude'])], tiles = 'OpenStreetMap',
                  zoom_start = 10)

# Add Choropleth Layer

Choropleth(geo_data = boroughs.__geo_interface__, data = gas_mean_join['Consumption (therms)'], 
          key_on = 'feature.properties.boro_name', fill_color = 'BuPu', legend_name = 'Average Therms Per Borough', 
          name = 'Borough Shapefiles').add_to(map5)

# Add Layer control

folium.LayerControl().add_to(map5)

# Display map

map5
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_d6fc472d2c92465a889145f281277f80%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js%22%3E%3C/script%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_d6fc472d2c92465a889145f281277f80%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_d6fc472d2c92465a889145f281277f80%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_d6fc472d2c92465a889145f281277f80%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# ## Combination Map

# %%
# Define new map 

map6 = folium.Map(location = [np.mean(gas['Latitude']), np.mean(gas['Longitude'])], tiles = 'OpenStreetMap',
                  zoom_start = 10)

# Add Choropleth Layer

Choropleth()

# Add MarkerCluster Layer

mc2 = MarkerCluster()

for idx, row in gas.iterrows():


# Add Layer control



# Display map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_c36e2fa2694c4716b50f4b0638758a4b%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css%22/%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D ...
